# %% [markdown]
# ### Librerías

# %%
import matplotlib.pyplot as plt   # librería para graficar
import numpy as np                # librería para manejo de vectores y utilidades matemáticas

# %% [markdown]
# # Funciones algebraicas

# %% [markdown]
# ### Función lineal
#
# Tiene la forma de $$f(x)=mx + b$$ donde $m$ y $b$  $\in R$.
#
# $m$ puede ser calculada por: $$m=\frac{y_{2}-y_{1}}{x_{2}-x_{1}}$$
#
# y $b$ es el punto de corte con el eje $y$. Su dominio es $Dom_{f} = (-\infty, \infty)$. Su imagen es $Im_{f} = (-\infty, \infty)$

# %%
def f(m, x, b):
  return m*x + b

# Numero de puntos a graficar
res = 100

# se define la pendiente, el corte con el eje "y" y los 
# puntos a analizar
m = 10
b = 5
# La función linspace tiene como parametros, desde comienza,
# hasta donde termina y num que es el numero de punto a crear
x = np.linspace(-10.0, 10.0, num=res)

y = f(m, x, b)

# Se crea la gráfica
fig, ax = plt.subplots()
# Se introduce los datos a graficar
ax.plot(x, y)
# Se crea una malla
ax.grid()
# Se crean los ejes coordenados
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')

# %% [markdown]
# ### Función Polinómicas
#
# Tiene la forma de $$P(x)=a_{n}x^{n} + a_{n-1}x^{n-1}+...+a_{2}x^{2}+a_{1}x + a_{0}$$
#
# a una función que tiene esta forma se le llama polinomio de grado $n$. A los elementos $a$ los llamaremoc coeficientes donde $a \in R$.
#
# **Por ejemplo:**
#
# $$P(x)= 2x^{7} - x^{4} + 3x^{2} + 4$$
#
# que es un polinómio de grado 7.
#
#
# ### Funciones potencia
#
# Hay unas funciones que son un caso particular de las funciones polinómicas que son las funciones potencia, las cuales tienen la forma:
#
#
# $$f(x)= x^{a}, a \in R$$
#
#
# **Por ejemplo:**
#
# $$f(x)= x^{2}$$
#
# El dominio de $f(x)=x^{2}$ es $Dom_{f} = (-\infty, \infty)$. Su imagen es $Im_{f} = [0, \infty)$

# %%
def f(x):
  return x**2

# Numero de puntos a graficar
res = 100

# La función linspace tiene como parametros, desde comienza,
# hasta donde termina y num que es el numero de punto a crear
x = np.linspace(-10.0, 10.0, num=res)

y = f(x)

# Se crea la gráfica
fig, ax = plt.subplots()
# Se introduce los datos a graficar
ax.plot(x, y)
# Se crea una malla
ax.grid()
# Se crean los ejes coordenados
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')

# %%
def f(x):
  return 2*x**7 - x**4 + 3*x**2 + 4

# Numero de puntos a graficar
res = 100

# La función linspace tiene como parametros, desde comienza,
# hasta donde termina y num que es el numero de punto a crear
x = np.linspace(-10.0, 10.0, num=res)

y = f(x)

# Se crea la gráfica
fig, ax = plt.subplots()
# Se introduce los datos a graficar
ax.plot(x, y)
# Se crea una malla
ax.grid()
# Se crean los ejes coordenados
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')

#RETO
#ax.set_xlim([5,7.5])
#ax.set_ylim([0,0.5])

# %% [markdown]
# # Funciones trascendentes
#
# Son funciones que no pueden ser expresadas con polinomios.

# %% [markdown]
# ### Funciones trigonométricas
#
# Algunos ejemplos son las funciones $cos(x)$, $sen(x)$ y $tan(x)$

# %% [markdown]
# ### Función exponencial
#
# Tienen la forma de $$f(x)=a^x$$ donde la base $a$ es una constante positiva. Un gran ejemplo de una función exponencial es usando la base como el número de euler:
#
# $$f(x)=e^x$$

# %% [markdown]
# ### Función logaritmo
#
# El logaritmo está definido por la **realación**:
#
# $$log_{b}(x) = n \Longleftrightarrow x=b^n$$
#
# donde:
#
#
#
# *   $b$ es la base.
# *   $n$ es el exponente al que está elevado la base.
# *   $x$ es el resultado de elevar la base $b$ al exponente $n$
#
# **Ejemplo:**
#
# Teniendo b=2 y n=8, entonces:
#
# $$2^8=256$$
#
# Por lo que $x=256$. Calculando el logaritmo base 2 de $x$ es:
#
# $$log_{2}(256) = 8$$

# %% [markdown]
# # Función seccionada
#
# Son funciones que tienen diferentes valores definidos por un intervalo. Por ejemplo la función escalón de Heaviside:
#
# $$H(x) =
#      \begin{cases}
#         0, &\quad \text{para, } x < 0 \\
#         1,  &\quad\text{para. } x \ge 0 \\
#      \end{cases}
# $$

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=26e20bed-8c88-4899-9c35-a6473208aa45' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
